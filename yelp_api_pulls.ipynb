# %%
pip install yelpapi
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import dependencies
import pandas as pd
import requests
from config import api_key

# %%
breweries_df = pd.read_csv("Resources/breweries.csv")
breweries_df.head()
# Out:
#    Unnamed: 0                       name           city state
# 0           0         NorthGate Brewing     Minneapolis    MN
# 1           1  Against the Grain Brewery     Louisville    KY
# 2           2   Jack's Abby Craft Lagers     Framingham    MA
# 3           3  Mike Hess Brewing Company      San Diego    CA
# 4           4    Fort Point Beer Company  San Francisco    CA

# %%
brewery_cities

# %%
# import yelpAPI
from yelpapi import YelpAPI
import argparse
from pprint import pprint

# %%
# set up argparser to accept api key
argparser = argparse.ArgumentParser()
argparser.add_argument('api_key', type=str, help='Yelp Fusion API Key')
args = argparser.parse_args()
# Out:
# usage: ipykernel_launcher.py [-h] api_key
# ipykernel_launcher.py: error: unrecognized arguments: -f
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2
# C:\Users\Brandon\anaconda3\envs\PythonData\lib\site-packages\IPython\core\interactiveshell.py:3452: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
with YelpAPI(api_key) as yelp_api:
    search_results = yelp_api.search_query(term='REI', location = "USA")

# %%
search_results
# Out:
# {'businesses': [{'id': 'QTpWiB9J94GpKfNdOMBvpA',
#    'alias': 'rei-san-francisco-2',
#    'name': 'REI',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/p-e9QMXU6Bti0osn88fGUA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rei-san-francisco-2?adjust_creative=sC0soDHEztCO8fHkc2WZkA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=sC0soDHEztCO8fHkc2WZkA',
#    'review_count': 504,
#    'categories': [{'alias': 'sportswear', 'title': 'Sports Wear'},
#     {'alias': 'outdoorgear', 'title': 'Outdoor Gear'},
#     {'alias': 'bikes', 'title': 'Bikes'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 37.77256, 'longitude': -122.40447},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '840 Brannan St',
#     'address2': '',
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94103',
#     'country': 'US',
#     'state': 'CA',
# ...
